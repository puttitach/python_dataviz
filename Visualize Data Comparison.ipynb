# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('C:\\Users\\Dell\\Downloads\\income.xls.xls', header = 3)

# %%
df
# Out:
#        ภาค และจังหวัด                                         Unnamed: 1  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2     ทั่วราชอาณาจักร                                                NaN
# 3            ตอนพิเศษ                                                NaN
# 4       กรุงเทพมหานคร                                                NaN
# ..                ...                                                ...
# 84           นราธิวาส                                                NaN
# 85                NaN                                                NaN
# 86                NaN                                                NaN
# 87             ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88            Source:  The Household Socio - Economic Survey, Nationa...
#
#        2541     2543     2545     2547     2549     2550     2552     2554  \
# ...

# %%
greaterbangkok = df.iloc[4:8,:]  #ตัดตาราง เลือกrowที่ต้องการ กทม สมุทรปราการ นน ปทุม
greaterbangkok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %% [markdown]
# โจทย์ : เทียบดูรายได้ของ4จังหวัด ในปี2541ของ

# %% [markdown]
# Barchart = กราฟแท่ง #มี input 2ตัว x คือ ตำแหน่งในแนวแกนนอน heigt คือความสูงของกราฟ

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2])   #คือตำแหน่ง
plt.title('Barchart compareing averange monthly incomes of provinces in Greater Bangkok in 1998')  #เพิ่มชื่อกราฟ  การบ้าน หาวิธีให้โชว์ชื่อกราฟเป็นภาษาไทย
plt.xlabel('provinces')   #เพิ่มชื่อแกนแต่ละแกน แกนx
plt.ylabel('incomes Bath/Month/Househoid')  #เพิ่มชื่อแกนแต่ละแกน แกนy
# Out:
# Text(0, 0.5, 'incomes Bath/Month/Househoid')

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2], tick_label=greaterbangkok.iloc[:,-1])   #คือตำแหน่ง # tick_label ใส่ชื่อแต่ละแกนโดยเลือกหลักและแถว
plt.title('Barchart compareing averange monthly incomes of provinces in Greater Bangkok in 1998')  #เพิ่มชื่อกราฟ  การบ้าน หาวิธีให้โชว์ชื่อกราฟเป็นภาษาไทย
plt.xlabel('provinces')   #เพิ่มชื่อแกนแต่ละแกน แกนx
plt.ylabel('incomes Bath/Month/Househoid')  #เพิ่มชื่อแกนแต่ละแกน แกนy
# Out:
# Text(0, 0.5, 'incomes Bath/Month/Househoid')

# %% [markdown]
# plot2กราฟ เทียบปี2541กับ2558

# %%
plt.bar([1-(0.35/2),2-(0.35/2),3-(0.35/2),4-(0.35/2)],greaterbangkok.iloc[:,-2],width=0.35, tick_label=greaterbangkok.iloc[:,-1], color='m', label='2558' ,align='edge')
plt.bar([1+(0.35/2),2+(0.35/2),3+(0.35/2),4+(0.35/2)],greaterbangkok.iloc[:,2],width=0.35, tick_label=greaterbangkok.iloc[:,-1], color='y', label='2541' ,align='edge')
plt.title('Barchart compareing averange monthly incomes of provinces in Greater Bangkok in 1998')  #เพิ่มชื่อกราฟ  การบ้าน หาวิธีให้โชว์ชื่อกราฟเป็นภาษาไทย
plt.xlabel('provinces')   #เพิ่มชื่อแกนแต่ละแกน แกนx
plt.legend(loc=0)   #ระบุสีว่าสีนี้ปีไหน แต่ละตำแหน่งมีคำสั่งที่แตกต่างกัน
plt.ylabel('incomes Bath/Month/Househoid')  #เพิ่มชื่อแกนแต่ละแกน แกนy
# Out:
# Text(0, 0.5, 'incomes Bath/Month/Househoid')

# %% [markdown]
# Stacked Barchart Graph กราฟแท่งที่ซ้อนกัน

# %%
saledata = pd.DataFrame([{'North':20, 'East':10, 'West':90, 'Sorth':120},    #สมมติข้อมูล
                                            {'North':220, 'East':20, 'West':50, 'Sorth':90}])
saledata
# Out:
#    North  East  West  Sorth
# 0     20    10    90    120
# 1    220    20    50     90

# %% [markdown]
# บริษัทไหน ขายดีกว่ากัน?

# %%
plt.bar([1,2],saledata.iloc[:,0], tick_label=['Company A', 'Company B']) 
plt.bar([1,2],saledata.iloc[:,1], bottom=saledata.iloc[:,0],tick_label=['Company A', 'Company B']) #bottomคือฐานมีอยู่เเล้ว ให้ต่อขึ้นไปซ้อนข้างบน
plt.bar([1,2],saledata.iloc[:,2], bottom=saledata.iloc[:,0]+saledata.iloc[:,1], tick_label=['Company A', 'Company B'])
plt.bar([1,2],saledata.iloc[:,3], bottom=saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2], tick_label=['Company A', 'Company B'])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar([1,2],saledata.iloc[:,0], tick_label=['Company A', 'Company B']) 
plt.bar([1,2],saledata.iloc[:,1], bottom=saledata.iloc[:,0],tick_label=['Company A', 'Company B']) #bottomคือฐานมีอยู่เเล้ว ให้ต่อขึ้นไปซ้อนข้างบน
plt.bar([1,2],saledata.iloc[:,2], bottom=saledata.iloc[:,0]+saledata.iloc[:,1], tick_label=['Company A', 'Company B'])
plt.bar([1,2],saledata.iloc[:,3], bottom=saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2], tick_label=['Company A', 'Company B'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Histogram = แผนภูมิความถี่

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#สุ่มตัวเลข fixing random state for reproducibility
np.random.seed(19680801)

# %%
np.random.randn()  #randn = normal distribution
# Out:
# 1.0493043103878812

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# %%
x
# Out:
# array([112.99148762, 108.267019  , 125.92116686, ...,  73.28843349,
#         77.0735325 , 107.25414148])

# %%
plt.hist(x, 50, density=True, facecolor= 'm', alpha=0.75);

# %% [markdown]
# Treemap

# %%
import squarify

# %%
volume = [350, 220, 170, 150, 50]

# %%
squarify.plot(sizes=volume)

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',    # \n คือขึ้นบรรทัดใหม่ 
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
          'Non-food\n volume: 50k']    #สร้างlistที่ตรงกับอันดับ labelของเรา
color_list = ['#818060', '#a5a084', '#d6cda7',
              '#b89179', '#7e716b', '#ab9e7e']  #สี โค้ดสี

# %%
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7)  #ความโปร่งใส

# %% [markdown]
# Radar chart = ใกล้ขอบนอกมากแสดงว่ามีค่ามาก ดีมากน้อย อันไหนมากกว่ากัน

# %%
import pandas as pd
from math import pi  #importค่าpi

# %%
pi   #ค่านี้เซ็ทไว้เเล้ว
# Out:
# 3.141592653589793

# %%
Example = pd.DataFrame([{'client_id':'c1', 'cheese':2, 'beer':2, 'chicken':5, 'bread':4, 'coffee':2},    #สมมติข้อมูล  ถ้าเป็นข้อความใส่ ' ' ด้วย
                                            {'client_id':'c2', 'cheese':5, 'beer':1, 'chicken':3, 'bread':3, 'coffee':3},
                                            {'client_id':'c3', 'cheese':4, 'beer':3, 'chicken':3, 'bread':2, 'coffee':5},
                                            {'client_id':'c4', 'cheese':3, 'beer':5, 'chicken':4, 'bread':1, 'coffee':3}])
Example
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(Example)[1:]  #ตัดแค่ตัวหัวแถว
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = Example.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.show()

# %% [markdown]
# Exemple 2

# %%
#เอาคนแรกกับคนที่2มาเปรียบเทียบกัน
#เตรียมพื้นที่
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)
plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = Example.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)
 
# part 2
val_c2=Example.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %% [markdown]
# word cloud = เจอในพารากราฟมากตัวน้นจะใหญ่

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
words = pd.read_csv('C:\\Users\\Dell\\Downloads\\message.csv')
words
# Out:
#      Unnamed: 0                       PartitionKey      RowKey  \
# 0             0  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168228
# 1             1  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168251
# 2             2  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168285
# 3             3  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168308
# 4             4  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168312
# ..          ...                                ...         ...
# 963         963  Uf9cb1d388c137ce49307370e6e9120e1  1582631314
# 964         964  Ufd3d31906486863b4dabc0b563c7802a  1582604220
# 965         965  Ufd3d31906486863b4dabc0b563c7802a  1582604226
# 966         966  Ufd3d31906486863b4dabc0b563c7802a  1582604239
# 967         967  Ufd3d31906486863b4dabc0b563c7802a  1582604245
#
#                             Timestamp                     message  \
# 0    2020-02-20 03:10:29.464192+00:00                       Hello
# 1    2020-02-20 03:10:52.853726+00:00  img : not a parasite image
# ...

# %%
# เว้นวรรค1ครั้งเเล้ว \ แปลว่า บรรทัดนี้ยังไม่จบ มีต่อ
text = ('Data science is an interdisciplinary field that uses scientific \
methods, processes, algorithms and systems to extract knowledge and insights \
from data in various forms, both structured and unstructured, similar to data \
mining. Data science is a concept to unify statistics, data analysis, machine \
learning and their related methods in order to understand and analyze actual \
phenomena with data. It employs techniques and theories drawn from many fields \
within the context of mathematics, statistics, information science, and \
computer science. Turing award winner Jim Gray imagined data science as a \
fourth paradigm of science (empirical, theoretical, computational and now \
data-driven) and asserted that everything about science is changing because of \
the impact of information technology and the data deluge. In 2012, when Harvard \
Business Review called it The Sexiest Job of the 21st Century, the term data \
science became a buzzword. It is now often used interchangeably with earlier \
concepts like business analytics, business intelligence, predictive modeling, \
and statistics. Even the suggestion that data science is sexy was paraphrasing \
Hans Rosling, featured in a 2011 BBC documentary with the quote, Statistics is \
now the sexiest subject around. Nate Silver referred to data science as a sexed \
up term for statistics. In many cases, earlier approaches and solutions are now \
simply rebranded as data science to be more attractive, which can cause the \
term to become dilute beyond usefulness. While many university programs now \
offer a data science degree, there exists no consensus on a definition or \
suitable curriculum contents. To its discredit, however, many data-science and \
big-data projects fail to deliver useful results, often as a result of poor \
management and utilization of resources')

wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='Blues').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
from PIL import Image

# %%
message = words.iloc[ :, -2]
message
# Out:
# 0                           Hello
# 1      img : not a parasite image
# 2                 img : Trichuris
# 3                   img : Ascaris
# 4                           อาการ
#                   ...
# 963                           บาย
# 964                       Dee kub
# 965                         ดีคับ
# 966                    สวัสดีครับ
# 967                            Hi
# Name: message, Length: 968, dtype: object

# %%
textMes = ' '

# %%
for i in range(len(words)) :
    w = words.iloc[i,4]
    textMes += w

# %%
wordcloud = WordCloud(width=1280, height=853, margin=0, colormap= 'pink_r'). generate(textMes)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.margins(x=0, y=0)

# %% [markdown]
# สร้าง word cloud เป็นภาษาไทย

# %%
regexp = r" [ก-๙ a-z A-Z]+"  #กำหนดคำตัวอย่างภาษาไทยกับภาษาอังกฤษ

# %%
path =  'C://Python//python_dataviz//THSarabunNew.ttf'

# %%
wordcloud = WordCloud(
                                            font_path=path,
                                            relative_scaling = 0.3,
                                            min_font_size=1,
                                            background_color="white",
                                            width=1024,
                                            height=768,
                                            max_words=2000,
                                            colormap='Set1',
                                            scale=3,
                                            font_step=4,
                                            collocations=False,
                                            regexp=regexp,
                                            margin=2
                                            ).generate(textMes)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 15))
ax.imshow(wordcloud, interpolation= 'bilinear')
ax.axis("off")
fig.show()
# Out:
# c:\users\dell\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
